# %% [markdown]
# # Grant's Kronos Demo — Colab Runner
#
# Runs `update_predictions.py` end-to-end on Google Colab's free GPU (T4) and displays the generated BTC/USDT forecast chart inline.
#
# ## Before you click Run All
#
# 1. **Runtime → Change runtime type → Hardware accelerator: `T4 GPU`** (free tier). Without this, inference will still run on CPU but will be much slower.
# 2. If you've forked this project to your own GitHub, replace the `REPO_URL` in the next cell.
# 3. Expected runtime on T4: roughly 2–5 minutes for 30 Monte Carlo samples of 144 candles.

# %% [markdown]
# ## 1. Check GPU availability

# %%
# !nvidia-smi | head -n 20

# %% [markdown]
# ## 2. Get the code
#
# Option A (preferred): clone your fork of the repo. Edit `REPO_URL` below.
#
# Option B: if you haven't pushed to GitHub yet, upload `Grants_Kronos_demo/` as a zip via the folder icon on the left, then unzip it — and skip the clone cell.

# %%
REPO_URL = 'https://github.com/YOUR_USERNAME/Grants_Kronos_demo.git'  # <-- edit me
# !git clone {REPO_URL} Grants_Kronos_demo || echo 'Clone failed — use Option B (upload zip) instead.'

# %% [markdown]
# ## 3. Install dependencies

# %%
# %cd /content/Grants_Kronos_demo
# !pip install -q -r requirements.txt

# %% [markdown]
# ## 4. Run the forecast
#
# This will:
# 1. Download the Kronos-Base weights (~400MB) from Hugging Face on first run
# 2. Fetch recent BTC/USDT 5-min candles from Binance and resample to 10-min
# 3. Run 30 Monte Carlo samples of a 24h forecast
# 4. Save `prediction_chart_btcusdt.png` and update `index.html`

# %%
# !python update_predictions.py

# %% [markdown]
# ## 5. View the chart inline

# %%
from IPython.display import Image, display
display(Image(filename='prediction_chart_btcusdt.png'))

# %% [markdown]
# ## 6. (Optional) Push the refreshed chart + HTML back to GitHub Pages
#
# Uncomment and fill in if you want this Colab run to publish to your GitHub-Pages-backed fork. Requires a GitHub personal access token stored as a Colab secret named `GH_TOKEN` (🔑 icon in the left sidebar).

# %%
# from google.colab import userdata
# GH_TOKEN = userdata.get('GH_TOKEN')
# GH_USER = 'YOUR_USERNAME'
# !git config user.email 'colab@example.com'
# !git config user.name 'Colab Runner'
# !git add prediction_chart_btcusdt.png index.html
# !git commit -m 'Auto-update forecast (Colab run)'
# !git push https://{GH_USER}:{GH_TOKEN}@github.com/{GH_USER}/Grants_Kronos_demo.git HEAD:main
